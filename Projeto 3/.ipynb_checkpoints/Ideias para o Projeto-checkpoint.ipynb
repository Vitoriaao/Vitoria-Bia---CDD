# %% [markdown]
# ### **IDEIAS PARA O PROJETO 3**

# %%
import pandas as pd

# %% [markdown]
# **IDEIA 1 - Regressão**
#
# Predição do sucesso de um artista no spotify.
#
# Pergunta: Qual a probabilidade de um artista permanecer no top 10 do spotify por dois anos consecutivos?

# %%
pd.read_csv('featuresdf.csv')
# Out:
#                        id                                               name  \
# 0   7qiZfU4dY1lWllzX7mPBI                                       Shape of You
# 1   5CtI0qwDJkDQGwXD1H1cL                                  Despacito - Remix
# 2   4aWmUDTfIPGksMNLV2rQP                 Despacito (Featuring Daddy Yankee)
# 3   6RUKPb4LETWmmr3iAEQkt                           Something Just Like This
# 4   3DXncPQOG4VBw3QHh3S81                                        I'm the One
# 5   7KXjTSCq5nL1LoYtL7XAw                                            HUMBLE.
# 6   3eR23VReFzcdmS7TYCrhC                    It Ain't Me (with Selena Gomez)
# 7   3B54sVLJ402zGa6Xm4YGN                                      Unforgettable
# 8   0KKkJNfGyhkQ5aFogxQAP                                 That's What I Like
# 9   3NdDpSvN911VPGivFlV5d  I Don’t Wanna Live Forever (Fifty Shades Darke...
# 10  7GX5flRQZVHRAGd6B4TmD                                      XO TOUR Llif3
# ...

# %% [markdown]
# **IDEIA 2 - Regressão**
#
# Predição do sucesso de um videogame.
#
# Pergunta: Qual é a probabilidade de um videogame novo chegar ao top 5 no ranking dos mais vendidos?

# %%
pd.read_csv('vgsales.csv')
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# ...

# %% [markdown]
# **IDEIA 3 - Classificação**
#
# Analisar a propensão de uma pessoa a cometer suicídio.
#
# Pergunta: Qual a probabilidade de uma pessoa cometer suicídio?

# %%
pd.read_csv('who_suicide_statistics.csv')
# Out:
#                     country  year     sex          age  suicides_no  \
# 0                   Albania  1985  female  15-24 years          NaN
# 1                   Albania  1985  female  25-34 years          NaN
# 2                   Albania  1985  female  35-54 years          NaN
# 3                   Albania  1985  female   5-14 years          NaN
# 4                   Albania  1985  female  55-74 years          NaN
# 5                   Albania  1985  female    75+ years          NaN
# 6                   Albania  1985    male  15-24 years          NaN
# 7                   Albania  1985    male  25-34 years          NaN
# 8                   Albania  1985    male  35-54 years          NaN
# 9                   Albania  1985    male   5-14 years          NaN
# 10                  Albania  1985    male  55-74 years          NaN
# 11                  Albania  1985    male    75+ years          NaN
# 12                  Albania  1986  female  15-24 years          NaN
# ...
